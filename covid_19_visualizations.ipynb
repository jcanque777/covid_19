# %%
import pandas as pd
import numpy as np

# %%
from IPython.display import display
pd.options.display.max_columns = None
# Out:
#           date state  positive  negative  pending  hospitalizedCurrently  \
# 0     20200404    AK     171.0    5869.0      NaN                    NaN
# 1     20200404    AL    1580.0    9273.0      NaN                    NaN
# 2     20200404    AR     743.0    9627.0      NaN                   72.0
# 3     20200404    AS       NaN      20.0      6.0                    NaN
# 4     20200404    AZ    2019.0   25141.0      NaN                    NaN
# ...        ...   ...       ...       ...      ...                    ...
# 1648  20200304    OR       3.0      29.0     18.0                    NaN
# 1649  20200304    SC       0.0       5.0      0.0                    NaN
# 1650  20200304    TX       1.0       NaN      NaN                    NaN
# 1651  20200304    WA      39.0       NaN      NaN                    NaN
# 1652  20200304    WI       1.0      19.0      6.0                    NaN
#
#       hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# ...

# %% [markdown]
# # Get Data

# %%
df = pd.read_csv("states-daily.csv")

# %%
df.head()
# Out:
#        date state  positive  negative  pending  hospitalizedCurrently  \
# 0  20200404    AK     171.0    5869.0      NaN                    NaN
# 1  20200404    AL    1580.0    9273.0      NaN                    NaN
# 2  20200404    AR     743.0    9627.0      NaN                   72.0
# 3  20200404    AS       NaN      20.0      6.0                    NaN
# 4  20200404    AZ    2019.0   25141.0      NaN                    NaN
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                    16.0             NaN              NaN
# 1                   212.0             NaN              NaN
# 2                     NaN             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                   297.0             NaN            104.0
#
#    onVentilatorCurrently  onVentilatorCumulative  recovered  \
# 0                    NaN                     NaN        NaN
# 1                    NaN                     NaN        NaN
# ...

# %%
df.columns
# Out:
# Index(['date', 'state', 'positive', 'negative', 'pending',
#        'hospitalizedCurrently', 'hospitalizedCumulative', 'inIcuCurrently',
#        'inIcuCumulative', 'onVentilatorCurrently', 'onVentilatorCumulative',
#        'recovered', 'hash', 'dateChecked', 'death', 'hospitalized', 'total',
#        'totalTestResults', 'posNeg', 'fips', 'deathIncrease',
#        'hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease',
#        'totalTestResultsIncrease'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# date                           0
# state                          0
# positive                       8
# negative                     146
# pending                     1186
# hospitalizedCurrently       1538
# hospitalizedCumulative      1192
# inIcuCurrently              1618
# inIcuCumulative             1583
# onVentilatorCurrently       1620
# onVentilatorCumulative      1610
# recovered                   1503
# hash                           0
# dateChecked                    0
# death                        681
# hospitalized                1192
# total                          0
# totalTestResults               0
# posNeg                         0
# fips                           0
# deathIncrease                 56
# hospitalizedIncrease          56
# negativeIncrease              56
# positiveIncrease              56
# totalTestResultsIncrease      56
# dtype: int64

# %%
df["date"][0]
# Out:
# 20200404

# %%
from datetime import datetime, timedelta

# %%
import copy
from copy import deepcopy

# %%
df["date"] = pd.to_datetime(df["date"], format = '%Y%m%d', errors = 'coerce')

# %%
df[df["state"] == "NY"]
# Out:
#            date state  positive  negative  pending  hospitalizedCurrently  \
# 37   2020-04-04    NY  113704.0  169917.0      NaN                15905.0
# 93   2020-04-03    NY  102863.0  157657.0      NaN                14810.0
# 149  2020-04-02    NY   92381.0  146584.0      NaN                13383.0
# 205  2020-04-01    NY   83712.0  137168.0      NaN                12226.0
# 261  2020-03-31    NY   75795.0  129391.0      NaN                10929.0
# 317  2020-03-30    NY   66497.0  119971.0      NaN                 9517.0
# 373  2020-03-29    NY   59513.0  112847.0      NaN                 8503.0
# 429  2020-03-28    NY   52318.0  103616.0      NaN                 7328.0
# 485  2020-03-27    NY   44635.0  101118.0      NaN                 6481.0
# 541  2020-03-26    NY   37258.0   84846.0      NaN                 5327.0
# 597  2020-03-25    NY   30811.0   72668.0      NaN                    NaN
# 653  2020-03-24    NY   25665.0   65605.0      NaN                    NaN
# ...

# %%
df['pos_test_percentage'] = df['positive']/df["total"]

# %%
df
# Out:
#            date state  positive  negative  pending  hospitalizedCurrently  \
# 0    2020-04-04    AK     171.0    5869.0      NaN                    NaN
# 1    2020-04-04    AL    1580.0    9273.0      NaN                    NaN
# 2    2020-04-04    AR     743.0    9627.0      NaN                   72.0
# 3    2020-04-04    AS       NaN      20.0      6.0                    NaN
# 4    2020-04-04    AZ    2019.0   25141.0      NaN                    NaN
# ...         ...   ...       ...       ...      ...                    ...
# 1648 2020-03-04    OR       3.0      29.0     18.0                    NaN
# 1649 2020-03-04    SC       0.0       5.0      0.0                    NaN
# 1650 2020-03-04    TX       1.0       NaN      NaN                    NaN
# 1651 2020-03-04    WA      39.0       NaN      NaN                    NaN
# 1652 2020-03-04    WI       1.0      19.0      6.0                    NaN
#
#       hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# ...

# %%
df["dateChecked"]
# Out:
# 0       2020-04-04T20:00:00Z
# 1       2020-04-04T20:00:00Z
# 2       2020-04-04T20:00:00Z
# 3       2020-04-04T20:00:00Z
# 4       2020-04-04T20:00:00Z
#                 ...
# 1648    2020-03-04T21:00:00Z
# 1649    2020-03-04T21:00:00Z
# 1650    2020-03-04T21:00:00Z
# 1651    2020-03-04T21:00:00Z
# 1652    2020-03-04T21:00:00Z
# Name: dateChecked, Length: 1653, dtype: object

# %%
s = deepcopy(df["date"][0])

# %%
s
# Out:
# 20200404

# %%
s
# Out:
# 20200404

# %%
date= datetime(year = (s[0:4]), month = (s[4:6]), day = (s[6:8]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-fc3079bfbbdb> in <module>
# ----> 1 date= datetime(year = (s[0:4]), month = (s[4:6]), day = (s[6:8]))
#
# IndexError: invalid index to scalar variable.

# %% [markdown]
# ## County Data

# %%
ls
# Out:
# COVID.DATA.LIC.AGMT.pdf        custom_license/
# README.md                      json_schema.txt
# biorxiv_medrxiv/               metadata.csv
# comm_use_subset/               metadata.readme
# county_date/                   noncomm_use_subset/
# covid19_workbook.ipynb         states-daily.csv
# covid_19_visualizations.ipynb

# %%
cd county_date/
# Out:
# /Users/johnrick/Desktop/DataScienceLearn/blog_covid19/county_date

# %%
cd covid-19-data/
# Out:
# /Users/johnrick/Desktop/DataScienceLearn/blog_covid19/county_date/covid-19-data

# %%
ls
# Out:
# LICENSE          README.md        us-counties.csv  us-states.csv

# %%
county = pd.read_csv("us-counties.csv")

# %%
ny = county[county['state'] == "New York"]

# %%
ny.head()
# Out:
#            date         county     state     fips  cases  deaths
# 416  2020-03-01  New York City  New York      NaN      1       0
# 448  2020-03-02  New York City  New York      NaN      1       0
# 482  2020-03-03  New York City  New York      NaN      2       0
# 518  2020-03-04  New York City  New York      NaN      2       0
# 519  2020-03-04    Westchester  New York  36119.0      9       0

# %%
ny
# Out:
#              date         county     state     fips  cases  deaths
# 416    2020-03-01  New York City  New York      NaN      1       0
# 448    2020-03-02  New York City  New York      NaN      1       0
# 482    2020-03-03  New York City  New York      NaN      2       0
# 518    2020-03-04  New York City  New York      NaN      2       0
# 519    2020-03-04    Westchester  New York  36119.0      9       0
# ...           ...            ...       ...      ...    ...     ...
# 32296  2020-04-04     Washington  New York  36115.0     17       1
# 32297  2020-04-04          Wayne  New York  36117.0     30       0
# 32298  2020-04-04    Westchester  New York  36119.0  13080     197
# 32299  2020-04-04        Wyoming  New York  36121.0     18       1
# 32300  2020-04-04          Yates  New York  36123.0      2       0
#
# [1086 rows x 6 columns]
